# %%
'''
@File    :   energy_ranges.ipynb
@Time    :   2023/07/06 02:59:54
@Author  :   Ravi K.
@Desc    :   A notebook comparing the lc files generated \
            for different energy ranges
'''

# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import os
import glob
import numpy as np
# %matplotlib inline
import matplotlib
params={
    'text.usetex':True,
    'font.family':'serif',
    'xtick.minor.visible':True,
    'ytick.minor.visible':True,
    'xtick.top':True,
    'ytick.left':True,
    'ytick.right':True,
    'xtick.direction':'out',
    'ytick.direction':'out',
    'xtick.minor.size':2.5,
    'xtick.major.size':5,
    'ytick.minor.size':2.5,
    'ytick.major.size':5,
    'axes.axisbelow':True
}
matplotlib.rcParams.update(params)

# %%
'''automate the generation of lc files for different energy ranges'''
n_bins = 8
energy_ranges = np.linspace(20, 200, n_bins+1)
d = "/home/ravioli/astro/ksp/grb/GRB190928A/1s"
os.mkdir(f"{d}/{n_bins}bins")
for i in range(n_bins):
    emin = energy_ranges[i]
    emax = energy_ranges[i+1]
    print(energy_ranges[i], energy_ranges[i+1])
    os.system("python3 pipelinev3.py -d {} -emin {} -emax {}".format(d, emin, emax))
    os.mkdir(f"{d}/{n_bins}bins/{int(emin)}-{int(emax)}")
    os.system(f"mv {d}/*.lc {d}/{n_bins}bins/{int(emin)}-{int(emax)}/")
# Out:
# 20.0 42.5
# 42.5 65.0
# 65.0 87.5
# 87.5 110.0
# 110.0 132.5
# 132.5 155.0
# 155.0 177.5
# 177.5 200.0

# %%
grb_time = (307372000, 307373000)

# %%
lc_2bin_1 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/20-100/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_2bin_2 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/100-200/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
plt.figure(figsize=(15, 5), dpi=200)
plt.plot(lc_2bin_1.TIME, lc_2bin_1.RATE+500, label="20-100 keV", alpha=0.8, color='slateblue')
plt.plot(lc_2bin_2.TIME, lc_2bin_2.RATE, label="100-200 keV", alpha=0.8, color='salmon')
plt.xlim(grb_time)
plt.xlabel("Time (s)", labelpad=10, fontsize=14)
plt.ylabel("Count rate (counts/s)", labelpad=10, fontsize=14)
plt.title("GRB190928A", pad=10, fontsize=16)
plt.legend()
plt.show()

# %%
lc_4bin_1 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/20-65/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_4bin_2 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/65-110/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_4bin_3 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/110-155/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_4bin_4 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/155-200/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
plt.figure(figsize=(15, 5), dpi=200)
plt.plot(lc_4bin_1.TIME, lc_4bin_1.RATE+750, label="20-65 keV", alpha=0.8, color='slateblue')
plt.plot(lc_4bin_2.TIME, lc_4bin_2.RATE+500, label="65-110 keV", alpha=0.8, color='black')
plt.plot(lc_4bin_3.TIME, lc_4bin_3.RATE+250, label="110-155 keV", alpha=0.8, color='darkseagreen')
plt.plot(lc_4bin_4.TIME, lc_4bin_4.RATE, label="155-200 keV", alpha=0.8, color='darkorange')
plt.xlim(grb_time)
plt.xlabel("Time (s)", labelpad=10, fontsize=14)
plt.ylabel("Count rate (counts/s)", labelpad=10, fontsize=14)
plt.title("GRB190928A", pad=10, fontsize=16)
plt.legend()
plt.show()

# %%
lc_6bin_1 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/6bins/20-50/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_6bin_2 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/6bins/50-80/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_6bin_3 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/6bins/80-110/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_6bin_4 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/6bins/110-140/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_6bin_5 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/6bins/140-170/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_6bin_6 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/6bins/170-200/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
plt.figure(figsize=(15, 10), dpi=200)
plt.plot(lc_6bin_1.TIME, lc_6bin_1.RATE+1000, label="20-50 keV", alpha=0.8, color='slateblue')
plt.plot(lc_6bin_2.TIME, lc_6bin_2.RATE+750, label="50-80 keV", alpha=0.8, color='black')
plt.plot(lc_6bin_3.TIME, lc_6bin_3.RATE+500, label="80-110 keV", alpha=0.8, color='darkseagreen')
plt.plot(lc_6bin_4.TIME, lc_6bin_4.RATE+250, label="110-140 keV", alpha=0.8, color='darkorange')
plt.plot(lc_6bin_5.TIME, lc_6bin_5.RATE, label="140-170 keV", alpha=0.8, color='salmon')
plt.plot(lc_6bin_6.TIME, lc_6bin_6.RATE-250, label="170-200 keV", alpha=0.8, color='darkviolet')
plt.xlim(grb_time)
plt.xlabel("Time (s)", labelpad=10, fontsize=14)
plt.ylabel("Count rate (counts/s)", labelpad=10, fontsize=14)
plt.title("GRB190928A", pad=10, fontsize=16)
plt.legend(loc = 'upper right')
plt.show()

# %%
lc_8bin_1 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/20-42/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_2 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/42-65/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_3 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/65-87/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_4 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/87-110/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_5 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/110-132/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_6 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/132-155/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_7 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/155-177/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_8bin_8 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/8bins/177-200/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
plt.figure(figsize=(15, 10), dpi=200)
plt.plot(lc_8bin_1.TIME, lc_8bin_1.RATE+1020, label="20-42 keV", alpha=0.8, color='slateblue')
plt.plot(lc_8bin_2.TIME, lc_8bin_2.RATE+875, label="42-65 keV", alpha=0.8, color='black')
plt.plot(lc_8bin_3.TIME, lc_8bin_3.RATE+750, label="65-87 keV", alpha=0.8, color='darkseagreen')
plt.plot(lc_8bin_4.TIME, lc_8bin_4.RATE+625, label="87-110 keV", alpha=0.8, color='darkorange')
plt.plot(lc_8bin_5.TIME, lc_8bin_5.RATE+500, label="110-132 keV", alpha=0.8, color='salmon')
plt.plot(lc_8bin_6.TIME, lc_8bin_6.RATE+375, label="132-155 keV", alpha=0.8, color='darkviolet')
plt.plot(lc_8bin_7.TIME, lc_8bin_7.RATE+250, label="155-177 keV", alpha=0.8, color='darkturquoise')
plt.plot(lc_8bin_8.TIME, lc_8bin_8.RATE+125, label="177-200 keV", alpha=0.8, color='darkgoldenrod')
plt.xlim(grb_time)
plt.xlabel("Time (s)", labelpad=10, fontsize=14)
plt.ylabel("Count rate (counts/s)", labelpad=10, fontsize=14)
plt.title("GRB190928A", pad=10, fontsize=16)
plt.legend(loc = 'upper right')
plt.show()

# %%
lc_10bin_1 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/20-38/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_2 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/38-56/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_3 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/56-74/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_4 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/74-92/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_5 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/92-110/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_6 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/110-128/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_7 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/128-146/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_8 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/146-164/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_9 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/164-182/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
lc_10bin_10 = fits.getdata("/home/ravioli/astro/ksp/grb/GRB190928A/1s/10bins/182-200/AS1A06_002T02_9000003206_21631cztM0_level2_quad_clean_Q0.lc")
plt.figure(figsize=(15, 10), dpi=200)
plt.plot(lc_10bin_1.TIME, lc_10bin_1.RATE+1100, label="20-38 keV", alpha=0.8, color='slateblue')
plt.plot(lc_10bin_2.TIME, lc_10bin_2.RATE+950, label="38-56 keV", alpha=0.8, color='black')
plt.plot(lc_10bin_3.TIME, lc_10bin_3.RATE+800, label="56-74 keV", alpha=0.8, color='darkseagreen')
plt.plot(lc_10bin_4.TIME, lc_10bin_4.RATE+700, label="74-92 keV", alpha=0.8, color='darkorange')
plt.plot(lc_10bin_5.TIME, lc_10bin_5.RATE+600, label="92-110 keV", alpha=0.8, color='darkorchid')
plt.plot(lc_10bin_6.TIME, lc_10bin_6.RATE+500, label="110-128 keV", alpha=0.8, color='darkturquoise')
plt.plot(lc_10bin_7.TIME, lc_10bin_7.RATE+400, label="128-146 keV", alpha=0.8, color='deeppink')
plt.plot(lc_10bin_8.TIME, lc_10bin_8.RATE+300, label="146-164 keV", alpha=0.8, color='darkkhaki')
plt.plot(lc_10bin_9.TIME, lc_10bin_9.RATE+200, label="164-182 keV", alpha=0.8, color='darkolivegreen')
plt.plot(lc_10bin_10.TIME, lc_10bin_10.RATE+100, label="182-200 keV", alpha=0.8, color='darkred')
plt.xlim(grb_time)
plt.xlabel("Time (s)", labelpad=10, fontsize=14)
plt.ylabel("Count rate (counts/s)", labelpad=10, fontsize=14)
plt.title("GRB190928A", pad=10, fontsize=16)
plt.legend(loc='upper right')
